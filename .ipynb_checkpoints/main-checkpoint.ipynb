# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a>b:
        return a
    else:
        return b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.286s
#
# OK

# %%
greater(3,2)
# Out:
# 3

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(a, b, c):
    if a > b:
        maximo = a
    if b > c:
        maximo = b
    else:
        maximo = c
    return maximo

# %%
greatest(1, 7, 6)
# Out:
# 7

# %%
test_greatest(greatest)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# TypeError: greatest() missing 2 required positional arguments: 'b' and 'c'
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.193s
#
# FAILED (errors=100)

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(*arr):
    suma_1 = 0
    for i in arr:
        suma_1 += i
    return suma_1

# %%
sum_all (2,4,5)
# Out:
# 11

# %%
test_sum(sum_all)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_sum.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 47, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/720770345.py", line 4, in sum_all
#     suma_1 += i
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.358s
#
# FAILED (errors=100)

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(*arr):
    multiplicacion = 1
    for i in arr:
         multiplicacion *= i
    return multiplicacion

# %%
mult_all(2,7,2)
# Out:
# 28

# %%
test_mult(mult_all)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-4, 7, -2, 4, 4, 1, -9, 2, -3, 4, -3, -3[157 chars]4, 1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [4, 8, -8, 10, -5, 4, -8, 1, 6, 9, -6, -7[187 chars], -2] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-4, 10, 3, -6, 4, -6, 10, -10, -4, -9, 6[100 chars]5, 8] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [1, 7, -7, 1, 9, -4, -2, 0, 3, -6, -4, 10[286 chars], -6] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-7, -4, 5, -4, -8, -6, 3, -7, 0, 9, 3, 1[86 chars], -6] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-1, -6, 3, 1, -4, -9, -9, 7, 6, -4, 8, 1[191 chars], -2] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-10, -6, -9, -7, 5, -3, -10, -6, 10, -5,[117 chars]8, 1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-10, 5, 2, -8, -10, -9, 9, -7, 10, -8, 4[147 chars], -7] != 11549213371596418855206912000000000000 : Should be 11549213371596418855206912000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [10, 8, 2, 9, -9, 5, -3, 6, -2, -1, 8, -8[38 chars]1, 6] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [0, 0, 7, -9, -10, 4, 2, 0, -5, -6, 5, -9[175 chars], -6] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-4, 9, 6, 3, 3, -10, -9, 1, -2, -2, -8, [199 chars]7, 5] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [1, 1, 9, 0, -10, -6, -5, 4, 3, 6, 1, -7,[179 chars], -4] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-1, -5, 6, -6, 6, 8, 8, -9, 2, 6, -6, -6[309 chars], -7] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-6, 4, -9, 1, 9, 5, 10, 3, 4, 2, -1, -5, 8, 9, 5, 3, 8, -9, -5, -8] != -36279705600000 : Should be -36279705600000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [6, -10, -9, 10, -2, 7, 7, 6, 2, -2, 5, 5[140 chars]0, 1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [9, 9, 3, -2, 5, 3, -8, 7, -2, 1, -5, -7,[82 chars], -3] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [10, -6, 6, -4, -1, 9, 3, 9, -1, -3, 10, [103 chars]0, 4] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [3, -9, -3, -4, -8, 9, 1, -10, 7, -3, -2,[63 chars], -2] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-2, 8, -8, 6, -8, 1, 10, 3, -4, -6, -7, [288 chars]7, 6] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [2, 8, -7, 1, 5, 6, -5, -2, 3, -3, 6, -5,[139 chars], -9] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [2, -10, -5, 1, -5, 2, 2, 3, 0, -4, 10, 3[149 chars]0, 8] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [6, 4, 5, 1, -9, -2, 8, -4, -3, 9, -6, 2,[301 chars], -1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [8, 2, -7, 4, -10, 0, 9, 6, 10, -6, 9, -2[142 chars], -5] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-10, 7, 0, -2, 5, -8, 6, -9, -4, -2, -5,[300 chars], -1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [
!= 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-4, 2, -10, -5, 4, 5, 3, 0, -2, 1, -6, -[37 chars], -1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [5, -2, 7, 8, -1, -3, 4, 5, 7, -1, -5, -8[292 chars], -3] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-9, 1, 5, 6, -6, 5, -10, 2, -5, 10, 8, 3[254 chars]2, 1] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-1, 2, 7, 4, -6, 3, 5, 3, -4, -1, 3, -2,[142 chars]9, 4] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [5, 10, 3, -2, 8, 4, 2, 6, 9, -2, 5, -9, [37 chars]9, 1] != -2902376448000000 : Should be -2902376448000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-1, -7, 5, 3, 2, -8, -2, 9, -8, -8, 1, 3, -4, 4, 8, -6, -5, -3] != 66886041600 : Should be 66886041600
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [8, -10, -10, 1, 2, 4, 8, -3, -10, 6, 1, [100 chars], -6] != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 63, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: [-8, 2, 3, 5, 8, 3, 8, 7, 9, -1, 5, 8, 5,[73 chars], -5] != 0 : Should be 0
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.208s
#
# FAILED (failures=100)

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    NO ENTIENDO QUE SE PIDE AQUI

# %%
# This will test your function 
test_operations(oper_all)

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    factorial_total = 1
    while n > 1:
        factorial_total *= n
        n -= 1
    return factorial_total

# %%
factorial (4)
# Out:
# 24

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.179s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(*arr):
    unique_values = []
    for i in arr:
        if i not in unique_values:
            unique_values.append(i)
    return unique_values

# %%
unique(1,2,3,3,4,5,8,7,5,5)
# Out:
# [1, 2, 3, 4, 5, 8, 7]

# %%
# This will test your function 
test_unique(unique)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
# TypeError: unhashable type: 'list'
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.169s
#
# FAILED (errors=100)

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(*arr):
    no_repetidos = []
    for i in arr:
        if i not in no_repetidos:
            no_repetidos.append(i)
    return no_repetidos

def mode_counter(*arr):
    no_repetidos = []
    n > 0
    for i in arr:
        if (i*n) > i not in no_repetidos:
            no_repetidos.append(i)
    return no_repetidos

# %%
mode_counter(1,1,2,2,3,4,5,6,6,6)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# This will test your function 
test_mode(mode_counter)

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
def st_dev(x):
    deviation_1 = 1/(1-x)
    return deviation_1

# %%
st_dev(4)
# Out:
# -0.3333333333333333

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
# ...
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/monicagoizuetabeltran/Documents/ironhack/labs/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/3085051933.py", line 3, in st_dev
#     deviation_1 = 1/(1-x)
# TypeError: unsupported operand type(s) for -: 'int' and 'list'
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.190s
#
# FAILED (errors=100)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(*string):
    alphabet ="abcdefghijklmnopqrstuvwz"
    for i in string:
        if alphabet in string:
            print ("true")
        else:
            print ("false")

# %%
pangram(Hola)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/1745847409.py in <module>
# ----> 1 pangram(bdsak)
#
# NameError: name 'bdsak' is not defined

# %%
# This will test your function 
test_pangram(pangram)

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(d):
    import re
    lst_1 = sorted(re.findall(r'\S+', string),key =str.lower)

    string_f = ""
    for i in lst_1:
        string_f += f"{i}"
    return string_f

# %%
a = "Hola Ana qué tal"

# %%
sort_alpha (a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/226015317.py in <module>
# ----> 1 sort_alpha (a)
#
# /var/folders/hb/9zbycmb97bx0n1b4ggqr8s_c0000gn/T/ipykernel_30866/2539955663.py in sort_alpha(d)
#       1 def sort_alpha(d):
#       2     import re
# ----> 3     lst_1 = sorted(re.findall(r'\S+', string),key =str.lower)
#       4
#       5     string_f = ""
#
# NameError: name 'string' is not defined

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    if string

# %%
# This will test your function 
test_pass(check_pass)
